# %%
# Install PyTorch
# !pip install torch==1.8.2+cu111 torchvision==0.9.2+cu111 torchaudio===0.8.2 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...
#      |█████████████▌                  | 834.1 MB 1.6 MB/s eta 0:11:49tcmalloc: large alloc 1147494400 bytes == 0x65f84000 @  0x7f3d68b59615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
# ...

# %%
# Install transformers
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 7.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 49.1 MB/s
# ...
#      |████████████████████████████████| 182 kB 62.2 MB/s
# ...

# %%
pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 7.2 MB/s
# ...

# %%
# Importing dependencies from transformers
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
# Load tokenizer 
tokenizer = PegasusTokenizer.from_pretrained("google/pegasus-xsum")
# Load model 
model = PegasusForConditionalGeneration.from_pretrained("google/pegasus-xsum")
# Out:
# Downloading:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/87.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.28G [00:00<?, ?B/s]

# %%
text = """ Abstract 
Recent work and research have shown immense advancements in many NLP tasks and have reached a benchmark by pre-training the model on a large corpus of text followed by fine-tuning it on a specific text.  By contrast, humans can perform any language task from only a few examples or following a few instructions - something the NLP system still struggles to do. However, scaling up language models improves text generation performance. Specifically, GPT-3(Generative Pre-trained Transformer, is a third-generation, autoregressive language model with 175 billion parameters that uses deep learning to produce human-like texts, and uses the previous distinction to analyze it. Earlier the general Ai was trained to do only a single task but with the advancements and use of transformers, we can train the model to do several tasks at once. The model achieves strong performances on many NLP tasks including translation, question-answering, and cloze tasks, as well as several tasks that require reasoning or domain adaptation, such as unscrambling words, using a novel word in a sentence, or performing 3-digit arithmetic. With time and advancements, it has been found that these models can have both beneficial and harmful applications.We discuss broader about the impacts and the model in general.
Introduction 
Gpt-3, Third-generation model is a generative pre-trained transformer based on a neural network that is trained using internet data. It can predominantly generate any type of text. The model has over 175 billion machine-learning parameters. Generating realistic human text has always been a challenge but so far GPT-3 has been proven to provide the most realistic human text. GPT-3 has been used to create articles, poetry, stories, news reports, and dialogue by using a small amount of text.
Gpt-3 models are also used for automated conversational tasks, text summarization, and programming code. Hence GPT-3 can be used in a wide range of ways, not just one. It has been trained in such a way that it can be used to perform many tasks at once. The model is based on the training method “Generative Pretraining” meaning trained to predict what the next token will be and GPT-3 is the size of a 2048-token-long-context. 
History 
Founded in 2015 by a non-profit, OpenAi San Francisco-based artificial intelligence research laboratory developed GPT-3 model as their research project with a motive to tackle larger goals or tasks hence developing “friendly ai” to benefit humanity in many ways.
The first version GPT-1 which contained an overall 117 million machine learning parameters was released in 2018. The second version GPT-2 with 1.5 billion parameters was released in November 2019. 
In May 2020, the latest version with over 175 billion parameters. The trainable parameters are 10x more than any previous model. On September 22, 2020, Microsoft licensed the exclusive rights of the GPT-3 model by investing $1 billion in OpenAI. Others still can use the public API but Microsoft has the access to the underlying model.
Also, the model was earlier released as a beta period where it would be used without any cost. However, the beta period ended on October 1, 2020, and the company released a pricing model on a credit-based system. A review in The New York Times on April 2022, described the capabilities of GPT-3 as being to write prose as fluent as that of humans.
Architecture
GPT-3 doesn't comprise one single model but it includes a family of models. Each model is trained with a different number of parameters. All the models are trained with over 300 billion tokens. 
The same transformer-based architecture of GPT-2 is used for GPT-3 including the modified initialization, pre-normalization, and reverse tokenization, with the exception that it uses alternating dense and sparse attention patterns in the layers of transformers. Pre-training, model, and data are very similar to GPT-2 model but model size, data size, and training time are much bigger.
The above table shows the 8 models which were trained ranging over three orders of magnitude from 125 million parameters to 175 billion parameters. Training models of different sizes allows us to test the model for validation loss and downstream language tasks. Here nparams is the total number of trainable parameters, nlayers is the total number of layers, dmodel is the number of units in each bottleneck layer (used feedforward layer four times the size of the bottleneck layer, dff = 4 ∗ dmodel), and dhead is the dimension of each attention head. All models use a context window of nctx = 2048 tokens. The model was partitioned across GPUs along both the depth and width dimensions to minimize data transfer between nodes. The precise architectural parameters for each model are chosen based on computational efficiency and load-balancing in the layout of models across GPUs.
The most giant version of GPT-3 has 175 billion parameters,96 attention layers, and a 3.2 million batch size. As mentioned before GPT-3 models are based on transformer architecture as shown below in the figure is the original transformer architecture.
The performance of the model depends on the training and fine-tuning of the model.
Evaluation
As the figure shown below evaluation of GPT-3 is done based on 3 conditions:
Few-shot(FS) leaning: Allowed as many demonstrations to fit into the model’s context window. It is similar to the basic machine learning model where the model is given some inputs and outputs and then expects the model to predict/perform on an unseen input. 
One-shot(1S) learning: Allowed only one demonstration. 
Zero-shot(0S) learning: No demonstration was allowed and only the instructions in natural language were given to the model. This learning can be considered as “unfairly hard” as it is hard for humans too to understand the task without example or demonstration.
Training Dataset
GPT-3 was trained on a mix of 5 different corpora/datasets which contained around trillion words. Each data set has some weight to it and they were sampled more often and trained with more than one epoch. The 5 datasets used were Common Crawl, WebText2, Books1, Books2, and Wikipedia. Train the model with over 300 billion tokens.

Dataset 
Quantity (tokens) 
Weight in training mix 
Epochs elapsed when training for 300B tokens
Common Crawl (filtered) 
 410 billion 
60% 
0.44
WebText2
19
22
2.9
Books1
12
8
1.9
Books2
55
8
0.43
Wikipedia
3
3
3.4
Above table mentioned the data sets which are used in training. “Weight in training mix” refers to the fraction of examples drawn from the dataset during training. 
Training process 
Training is done using next-word prediction. To train models of different sizes, the batch size is increased according to the parameters while the learning rate is decreased. To choose the batch size, the gradient noise scale is measured during the training. 175 billion parameters need 175 * 4 = 700GB memory (each parameter needs 4 bytes). To train the model without running out of memory, usage mixture of model parallelism within each matrix multiplied across the layers of the network is used. 
Limitations
High-quality text generator or GPT-3 has all the potential to excel and fail in the field of language model because of their beneficial and harmful applications. 

The model text generating capacity makes it difficult to distinguish synthetic text from human-written text so this could be a misuse of the language model by any author.
The model lacks long-term memory it doesn't learn anything from long-term interactions like humans.
As the model is so large it takes more time for the model to do the predictions.
The model has a fixed maximum input size means GPT-3 model can not deal be longer than a few sentences.
Although the model produces high-quality text, sometimes it starts losing coherency while formatting long sentences and repeating sequences over and over again. 
Due to the unidirectionality of the model it does not perform well on natural language interference tasks(determining if a sentence implies other sentences), fill-in-the-blanks, and reading comprehension tasks.
GPT’s generic language modeling objective is weighing each token equally which lacks the notion of task or goal-orientated prediction of tokens.
Model includes complex and costly inferencing due to its heavy architecture which results in less interpretability of the language. 
The model carries the potential risk of misuse of its human-like text-generating capability for phishing, spamming, spreading misinformation, or performing other fraudulent activities.
As the model scraped off everything from the internet, the articles generated by GPT-3 might be gender, ethnicity, race, or religious bias.

Developments that can be done to lower the limitations
Traditional security risk assessment frameworks can be used to protect the model being misused.
Bidirectional transformers can lower the coherency rate and repetition. 
Reinforcement learning to fine-tune the model

Applications of GPT-3 in the real-world
Assistance in question-answering system 
They are used as customer service providers and a chatbot that uses the GPT-3 model for assistance in question-answering interaction/system. Sometimes Customer service is delivered through a chatbot too. Some examples of this are ActiveChat allows users to chat with their customers in real-time, Replier.ai corresponds to customers' reviews, and AIBuddy is a powered version of WhatsApp. 
As software developers
The model is trained such that it can write the code, OpenAi developers have designed the Codex system which is based on GPT-3, Specifically designed to convert Natural language description into code. CoseStarter used Codex to assist code generation. Tailwind CSS is a code generator empowered by GPT-3 model that generates CSS code based on requirements. 
Writer, summarizer, and editor
The model has a collection of words and is trained to write high-quality articles and summarize log text into short. Writesonic is a well-known GPT-3 powered application that generates high-quality articles, emails, blogs, landing pages, and many more within a short period of time also boosts the website SEO for generating more traffic. Grok tool uses the model to summarize the on-demand and daily digest of channels. It can summarize up to 30 messages. Playground API is used to convert difficult text to easy-to-read and understandable text. 
Content generation
OthersideAI and Snazzy AI help in generating content within a few minutes the latter also helps in modifying texts as longer, shorter, causal, formal, and many more. 
Creative 
The model helps in domains that are additional such as the model is also used in games, language learning, and grammar corrections. Al Dungeon generates a new set of expiration options for the text adventure game using the model. Duolingo application uses GPT-3 model to correct the grammar of french sentences. Designer is an integration of the Figma plugin and GPT-3 uses to generate web templates. 
Future of GPT-3
OpenAI and other researchers are working and trying to build more powerful and large models. Several works are focused on increasing the machine learning parameters to improve generative and task performance. 2 weeks ago, OpenAI rolled out the “GPT-3.5” version i.e improved version of GPT-3. GPT.3.5 that's essentially a general-purpose chatbot but is trained with a blend of text and code. Just like GPT-3, this model learns the relationship between sentences, words, and parts of words by ingesting a lot of content from the web. Hence the language model has no end to advancements and improvements. 
Conclusion
Researchers have concluded that the models play an important role in developing adaptable, general language systems despite their limitations and weakness. The language models will keep improving and then provide the world with larger yet less complex language models. 


 





"""

# %%
# Create tokens - number representation of our text
tokens = tokenizer(text, truncation=True, padding="longest", return_tensors="pt")
# Input tokens
tokens
# Out:
# {'input_ids': tensor([[13609, 13618,   201,   111,   473,   133,  1673, 10693, 17067,   115,
#            223, 36789,  2722,   111,   133,  2455,   114, 11779,   141,  1133,
#            121, 18006,   109,   861,   124,   114,   423, 36343,   113,  1352,
#           1734,   141,  1226,   121, 42006,   126,   124,   114,   739,  1352,
#            107,  1060,  3945,   108,  4095,   137,  1798,   189,  1261,  1778,
#            135,   209,   114,   324,  2724,   132,   645,   114,   324,  2621,
#            233,   364,   109, 36789,   327,   309,  8293,   112,   171,   107,
#            611,   108, 16276,   164,  1261,  1581,  7997,  1352,  2233,   637,
#            107, 16736,   108,  9688,   930,  4866,   741, 40703, 47412,  3414,
#            121, 14787, 51979,   108,   117,   114,   776,   121, 11050,   108,
#           2253,   216, 69217,  1261,   861,   122, 17382,  1722,  5384,   120,
#           1481,  1355,   761,   112,  1449,   883,   121,  2134,  7721,   108,
# ...

# %%
# Summarize 
summary = model.generate(**tokens)
# Output summary tokens
summary[0]
# Out:
# tensor([   0,  222,  136,  800,  108,  145, 4094,  114,  177, 1261,  861,  120,
#          137, 3210,  189,  619,  113, 1352,  107,    1])

# %%
# Decode summary
tokenizer.decode(summary[0])
# Out:
# '<pad>In this paper, we introduce a new language model that can generate any type of text.</s>'
